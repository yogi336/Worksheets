# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'C:/Users/user/Downloads/PYTHON_WORKSHEET_12.csv')

# %%
df
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %% [markdown]
# Q1.Determine the no. of rows and no. of columns in the dataset.

# %%
r,c = df.shape
print("No. of rows: ",r)
print("No. of columns: ",c)
# Out:
# No. of rows:  23678
# No. of columns:  21

# %% [markdown]
# Q2 Display the datatypes of each column.

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms            float64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %% [markdown]
# Q3 Determine the row indexes of rows having all null values (i.e. empty rows)

# %%
df[df.isna().all(axis=1)].index
# Out:
# Int64Index([   31,  1145,  1348,  2119,  3277,  3288,  3745,  3752,  3798,
#              3855,
#             ...
#             21220, 21343, 21602, 22003, 22109, 22288, 22704, 22918, 23153,
#             23341],
#            dtype='int64', length=131)

# %% [markdown]
# Q4. Determine the total number of empty rows and their percentage in whole dataset and remove them.

# %%
missing = df.isnull().sum()

# %%
missing
# Out:
# Suburb             131
# Address            131
# Rooms              131
# Type               131
# Price             5282
# Method             131
# SellerG            131
# Date               131
# Distance           132
# Postcode           132
# Bedroom2          4612
# Bathroom          4615
# Car               4757
# Landsize          6268
# BuildingArea     13660
# YearBuilt        12138
# CouncilArea       8022
# Lattitude         4435
# Longtitude        4435
# Regionname         132
# Propertycount      132
# dtype: int64

# %%
missing_values_percentage=df.isnull().sum() * 100 / len(df)

# %%
missing_values_percentage
# Out:
# Suburb            0.553256
# Address           0.553256
# Rooms             0.553256
# Type              0.553256
# Price            22.307627
# Method            0.553256
# SellerG           0.553256
# Date              0.553256
# Distance          0.557480
# Postcode          0.557480
# Bedroom2         19.477996
# Bathroom         19.490666
# Car              20.090379
# Landsize         26.471830
# BuildingArea     57.690683
# YearBuilt        51.262776
# CouncilArea      33.879551
# Lattitude        18.730467
# Longtitude       18.730467
# Regionname        0.557480
# Propertycount     0.557480
# dtype: float64

# %%
remove  = df.isnull().dropna(how='all')

# %%
remove
# Out:
#        Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0       False    False  False  False   True   False    False  False     False
# 1       False    False  False  False  False   False    False  False     False
# 2       False    False  False  False  False   False    False  False     False
# 3       False    False  False  False   True   False    False  False     False
# 4       False    False  False  False  False   False    False  False     False
# ...       ...      ...    ...    ...    ...     ...      ...    ...       ...
# 23673   False    False  False  False   True   False    False  False     False
# 23674   False    False  False  False   True   False    False  False     False
# 23675   False    False  False  False  False   False    False  False     False
# 23676   False    False  False  False  False   False    False  False     False
# 23677   False    False  False  False  False   False    False  False     False
#
# ...

# %% [markdown]
# Q5 Determine the column names having missing values

# %%
df.columns[df.isnull().any()]
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
len(df.columns[df.isnull().any()])
# Out:
# 21

# %% [markdown]
# Q6. Determine the missing values and their percentage in each column.

# %%
percent= 100*(len(df.loc[:,df.isnull().sum(axis=0)>=21 ].index) / len(df.index))
print(round(percent,2))
# Out:
# 100.0

# %% [markdown]
# Q7 . Determine the row indexes having missing values.

# %%
df[df.isnull().any(axis=1)]
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h        NaN     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u        NaN     VB
# 5        Abbotsford    40 Federation La    3.0    h   850000.0     PI
# 7        Abbotsford        16 Maugie St    4.0    h        NaN     SN
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u        NaN     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h        NaN      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
t=df.isnull().any(axis = 1).sum()
t
# Out:
# 17482

# %% [markdown]
# Q8. Determine the missing values and their percentage in each row.

# %%
percent_missing = df.isnull().sum(axis=1) * 100 / len(df)
percent_missing
# Out:
# 0        0.012670
# 1        0.008447
# 2        0.000000
# 3        0.012670
# 4        0.000000
#            ...
# 23673    0.008447
# 23674    0.033787
# 23675    0.016893
# 23676    0.004223
# 23677    0.008447
# Length: 23678, dtype: float64

# %% [markdown]
#  Q9. Determine the column names having more than 30% missing values and remove them from the dataset.

# %%
def missing(dff):
    print (round((dff.isnull().sum() * 100/ len(dff)),2).sort_values(ascending=False))

missing(df)
# Out:
# BuildingArea     57.69
# YearBuilt        51.26
# CouncilArea      33.88
# Landsize         26.47
# Price            22.31
# Car              20.09
# Bathroom         19.49
# Bedroom2         19.48
# Longtitude       18.73
# Lattitude        18.73
# Distance          0.56
# Propertycount     0.56
# Postcode          0.56
# Regionname        0.56
# Date              0.55
# SellerG           0.55
# Method            0.55
# Type              0.55
# Rooms             0.55
# Address           0.55
# Suburb            0.55
# dtype: float64

# %% [markdown]
# Q12. Considering the 'Price' column as target variable which is to be predicted, how will you treat the missing values?
# Give a brief explanation and treat the missing values in 'Price' column

# %%
df['Price'].fillna(df['Price'].mode().iloc[0])
# Out:
# 0         600000.0
# 1        1480000.0
# 2        1035000.0
# 3         600000.0
# 4        1465000.0
#            ...
# 23673     600000.0
# 23674     600000.0
# 23675    1100000.0
# 23676    1285000.0
# 23677    1050000.0
# Name: Price, Length: 23678, dtype: float64

# %% [markdown]
# Q13. Now check the percentage of missing values in each column again, if missing values exist, treat it with the most
# suitable method.

# %%
def miss_data(df):
    x = ['column_name','missing_data', 'missing_in_percentage']
    missing_data = pd.DataFrame(columns=x)
    columns = df.columns
    for col in columns:
        icolumn_name = col
        imissing_data = df[col].isnull().sum()
        imissing_in_percentage = (df[col].isnull().sum()/df[col].shape[0])*100
        
        missing_data.loc[len(missing_data)] = [icolumn_name, imissing_data, imissing_in_percentage]
    print(missing_data) 
    
miss_data(df)
# Out:
#       column_name missing_data  missing_in_percentage
# 0          Suburb          131               0.553256
# 1         Address          131               0.553256
# 2           Rooms          131               0.553256
# 3            Type          131               0.553256
# 4           Price         5282              22.307627
# 5          Method          131               0.553256
# 6         SellerG          131               0.553256
# 7            Date          131               0.553256
# 8        Distance          132               0.557480
# 9        Postcode          132               0.557480
# 10       Bedroom2         4612              19.477996
# 11       Bathroom         4615              19.490666
# 12            Car         4757              20.090379
# 13       Landsize         6268              26.471830
# 14   BuildingArea        13660              57.690683
# 15      YearBuilt        12138              51.262776
# ...

# %%
df.fillna(df.mode().iloc[0])
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St    2.0    h   600000.0     SS
# 1        Abbotsford        85 Turner St    2.0    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St    2.0    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St    3.0    u   600000.0     VB
# 4        Abbotsford        5 Charles St    3.0    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23673  Wyndham Vale     25 Clitheroe Dr    3.0    u   600000.0     PN
# 23674  Wyndham Vale    19 Dalrymple Bvd    4.0    h   600000.0      S
# 23675     Yallambie        17 Amaroo Wy    4.0    h  1100000.0      S
# 23676    Yarraville          6 Agnes St    4.0    h  1285000.0     SP
# 23677    Yarraville       33 Freeman St    4.0    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...
